# %%
# Texto retirado da internet que podemos usar como base
'''
Métodos de etapa única
As duas funções ode23 e ode45 são solucionadores de ODE de etapa única. 
Eles também são conhecidos como métodos Runge-Kutta. Cada etapa é quase independente das etapas anteriores. 
Duas informações importantes são passadas de uma etapa para a próxima. 
O tamanho do passohesperada para atingir a precisão desejada é passada passo a passo.
E, em uma estratégia conhecida como FSAL, para Primeiro Igual ao Último, 
o valor da função final no final de uma etapa bem-sucedida é usado no valor da função inicial na etapa seguinte.

https://blogs.mathworks.com/cleve/2014/05/26/ordinary-differential-equation-solvers-ode23-and-ode45/

'''
# Out:
# '\nMétodos de etapa única\nAs duas funções ode23 e ode45 são solucionadores de ODE de etapa única. \nEles também são conhecidos como métodos Runge-Kutta. Cada etapa é quase independente das etapas anteriores. \nDuas informações importantes são passadas de uma etapa para a próxima. \nO tamanho do passohesperada para atingir a precisão desejada é passada passo a passo.\nE, em uma estratégia conhecida como FSAL, para Primeiro Igual ao Último, \no valor da função final no final de uma etapa bem-sucedida é usado no valor da função inicial na etapa seguinte.\n\nhttps://blogs.mathworks.com/cleve/2014/05/26/ordinary-differential-equation-solvers-ode23-and-ode45/\n\n'
