# %%
# Diferença dividida finita regressiva
def f(x):
    if x==1.25:
        return 2.615
    elif x==1.30:
        return 3.737
    elif x==1.35:
        return 3.997
    elif x==1.40:
        return 4.593
    elif x==1.45:
        return 5.781
x = 1.40
h = 0.05
# ( fx(x+h) - fx(x-h) ) / 2*h Primeira diferença dividida centrada
a = (f(1.45) - f(1.35)) / (2*0.05)
print(f' A primeira derivada é {a}\n')
# ( fx(x+h) - 2*fx(x) + fx(x-h) ) / h**2 # Segunda diferença dividida centrada
b = ( f(1.45) - 2*f(1.40) + f(1.35)) / (0.05**2)
print(f' A segunda derivada é {b}\n')
# ( f(x) - 3*f(x-h) + 3*f(x - 2*h) - f(x-3*h) ) / (0.05**3) # Terceira diferença dividida regressiva
c = ( f(1.40) - 3*f(1.35) + 3*f(1.30) - f(1.25) ) / (0.05**3)
print(f' A terceira derivada é {c}\n')
# Out:
#  A primeira derivada é 17.839999999999996
#
#  A segunda derivada é 236.7999999999998
#
#  A terceira derivada é 9584.0
