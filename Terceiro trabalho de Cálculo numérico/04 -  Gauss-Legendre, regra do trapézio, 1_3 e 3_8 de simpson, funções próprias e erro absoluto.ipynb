# %%
# 4.a
# Quadratura de gauss
# Definir a função de integração
import numpy as np
def f(x):
    return np.cos(x**2)
from sympy import *
v = Symbol('v')
y = cos(v**2)
# Calculando as derivadas para o erro de truncamento
y4 = y.diff( v, n = 4)
y6 = y.diff( v, n = 6)
y8 = y.diff( v, n = 8)
y10 = y.diff( v, n = 10)
y12 = y.diff( v, n = 12)

#  I ~= c1.f(x1) + c2.f(x2) + ... + cn.f(xn)
# para 2 pontos, temos:
n = 2
c = np.array([ 1.0000000, 1.0000000])
x = np.array([ -0.577350269, 0.577350269])
soma = 0
for i in range(0,n,1):
    soma += (c[i])*(f(x[i]))
print(f' A integral pelo método de Gauss-Lagendre utilizando {n} pontos, temos I = {soma}\n')
m = []
a = x[0]
b = x[n-1]
while (a <= b):
    m.append(float(nsolve(y4,v,2)))
    a += 0.0001
print(f'O erro de trucamento associado para a função {y} em {n} pontos é aproximadamente {max(m)}\n')
# para 3 pontos, temos:
n = 3
c = np.array([ 0.5555556, 0.8888889, 0.5555556])
x = np.array([ -0.774596669, 0.0, 0.774596669])
soma = 0
for i in range(0,n,1):
    soma += (c[i])*(f(x[i]))
print(f' A integral pelo método de Gauss-Lagendre utilizando {n} pontos, temos I = {soma}\n')
m = []
a = x[0]
b = x[n-1]
while (a <= b):
    m.append(float(nsolve(y6,v,2)))
    a += 0.0001
print(f'O erro de trucamento associado para a função {y} em {n} pontos é aproximadamente {max(m)}\n')
# para 4 pontos, temos:
n = 4
c = np.array([ 0.3478548, 0.6521452, 0.6521452, 0.3478548])
x = np.array([ -0.861136312, -0.339981044, 0.339981044, 0.861136312])
soma = 0
for i in range(0,n,1):
    soma += (c[i])*(f(x[i]))
print(f' A integral pelo método de Gauss-Lagendre utilizando {n} pontos, temos I = {soma}\n')
m = []
a = x[0]
b = x[n-1]
while (a <= b):
    m.append(float(nsolve(y8,v,2)))
    a += 0.0001
print(f'O erro de trucamento associado para a função {y} em {n} pontos é aproximadamente {max(m)}\n')
# para 5 pontos, temos:
n = 5
c = np.array([  0.2369269, 0.4786287, 0.5688889, 0.4786287,  0.2369269])
x = np.array([ -0.906179846, -0.538469310, 0.0, 0.538469310, 0.906179846])
soma = 0
for i in range(0,n,1):
    soma += (c[i])*(f(x[i]))
print(f' A integral pelo método de Gauss-Lagendre utilizando {n} pontos, temos I = {soma}\n')
m = []
a = x[0]
b = x[n-1]
while (a <= b):
    m.append(float(nsolve(y10,v,2)))
    a += 0.0001
print(f'O erro de trucamento associado para a função {y} em {n} pontos é aproximadamente {max(m)}\n')
# para 6 pontos, temos:
n = 6
c = np.array([ 0.1713245, 0.3607616, 0.4679139, 0.4679139, 0.3607616, 0.1713245])
x = np.array([ -0.932469514, -0.661209386, -0.238619186, 0.238619186, 0.661209386, 0.932469514])
soma = 0
for i in range(0,n,1):
    soma += (c[i])*(f(x[i]))
print(f' A integral pelo método de Gauss-Lagendre utilizando {n} pontos, temos I = {soma}\n')
m = []
a = x[0]
b = x[n-1]
while (a <= b):
    m.append(float(nsolve(y12,v,2)))
    a += 0.0001
print(f'O erro de trucamento associado para a função {y} em {n} pontos é aproximadamente {max(m)}\n')
# Out:
#  A integral pelo método de Gauss-Lagendre utilizando 2 pontos, temos I = 1.889913892772761
#
# O erro de trucamento associado para a função cos(v**2) em 2 pontos é aproximadamente 1.772453850905516
#
#  A integral pelo método de Gauss-Lagendre utilizando 3 pontos, temos I = 1.8059285457197363
#
# O erro de trucamento associado para a função cos(v**2) em 3 pontos é aproximadamente 1.772453850905516
#
#  A integral pelo método de Gauss-Lagendre utilizando 4 pontos, temos I = 1.8086164181088362
#
# O erro de trucamento associado para a função cos(v**2) em 4 pontos é aproximadamente 1.772453850905516
#
#  A integral pelo método de Gauss-Lagendre utilizando 5 pontos, temos I = 1.8090591870206953
#
# O erro de trucamento associado para a função cos(v**2) em 5 pontos é aproximadamente 1.772453850905516
#
#  A integral pelo método de Gauss-Lagendre utilizando 6 pontos, temos I = 1.8090493761325195
#
# O erro de trucamento associado para a função cos(v**2) em 6 pontos é aproximadamente 1.772453850905516

# %%
# 4.b
# Método do Trapézio
# Definir a função de integração
import numpy as np
def f(x):
    return np.cos(x**2)
# Aplicando o método do trapézio
def metodo_do_trapezio( limite_inferior, limite_superior, sub_intervalo):
    # dividindo em intervalos
    h = (limite_superior - limite_inferior) / sub_intervalo
    # encontrando a soma
    integracao = f(limite_inferior) + f(limite_superior)
    for i in range(1,sub_intervalo):
        k = limite_inferior + i*h
        integracao = integracao + 2 * f(k)
    # encontrando o valor da integração final
    integracao = integracao * h/2
    return integracao
for sub_intervalo in range(1,17):
    # Entradas do intervalo e do sub intervalo
    limite_inferior = 0
    limite_superior = np.pi
    # Chamamento do metodo do trapézio
    r1 = metodo_do_trapezio( limite_inferior, limite_superior, sub_intervalo)
    print(f'Integração pelo método do trapézio é igual a {r1}')
# Out:
# Integração pelo método do trapézio é igual a 0.15286147601890632
# Integração pelo método do trapézio é igual a -1.1506940325661925
# Integração pelo método do trapézio é igual a 0.19383724773570976
# Integração pelo método do trapézio é igual a 0.64976090026659
# Integração pelo método do trapézio é igual a 0.6574123708042644
# Integração pelo método do trapézio é igual a 0.632540104917638
# Integração pelo método do trapézio é igual a 0.6145106201633687
# Integração pelo método do trapézio é igual a 0.6026213017559421
# Integração pelo método do trapézio é igual a 0.5945599796170709
# Integração pelo método do trapézio é igual a 0.58887593927856
# Integração pelo método do trapézio é igual a 0.5847242565020948
# Integração pelo método do trapézio é igual a 0.5816002438547104
# Integração pelo método do trapézio é igual a 0.5791902247043186
# Integração pelo método do trapézio é igual a 0.5772915650463515
# Integração pelo método do trapézio é igual a 0.5757687816836118
# Integração pelo método do trapézio é igual a 0.5745285296142896

# %%
# 4.c
# 1/3 de simpson
# função para integrar
import numpy as np
def f(x):
    return np.cos(x**2)
# implementando a regra de 1/3 de simpson
def regra_de_simpson( limite_inferior, limite_superior, sub_intervalo):
    # Calculando o intervalo
    h = (limite_superior - limite_inferior) / sub_intervalo
    # encontrando a soma 
    integracao = f(limite_inferior) + f(limite_superior)
    for i in range(1,sub_intervalo):
        k = limite_inferior + i*h
        if i%2 == 0:
            integracao = integracao + 2 * f(k)
        else:
            integracao = integracao + 4 * f(k)
    # encontrando valor final da intergração
    integracao = integracao * h/3
    return integracao
for sub_intervalo in range(1,17):
    # entradas da integração
    limite_inferior = 0
    limite_superior = np.pi
    # Chamando a funcao pela regra de 1/3 de simpson
    r2 = regra_de_simpson( limite_inferior, limite_superior, sub_intervalo)
    print(f'A integração pela regra de 1/3 de simpson é {r2}')
# Out:
# A integração pela regra de 1/3 de simpson é 0.10190765067927088
# A integração pela regra de 1/3 de simpson é -1.5852125354278923
# A integração pela regra de 1/3 de simpson é 0.44799413547365585
# A integração pela regra de 1/3 de simpson é 1.249912544544184
# A integração pela regra de 1/3 de simpson é 0.4410159282556298
# A integração pela regra de 1/3 de simpson é 0.7787743906449472
# A integração pela regra de 1/3 de simpson é 0.7261308576091884
# A integração pela regra de 1/3 de simpson é 0.5869081022523928
# A integração pela regra de 1/3 de simpson é 0.7233897321609488
# A integração pela regra de 1/3 de simpson é 0.5660304621033252
# A integração pela regra de 1/3 de simpson é 0.690579747498426
# A integração pela regra de 1/3 de simpson é 0.5646202901670679
# A integração pela regra de 1/3 de simpson é 0.6663711275747932
# A integração pela regra de 1/3 de simpson é 0.5648852133406795
# A integração pela regra de 1/3 de simpson é 0.6495196335894494
# A integração pela regra de 1/3 de simpson é 0.5651642722337388

# %%
# 4.d
# regra de 3/8 de simpson
# a função de integração
import numpy as np
def f(x):
    return np.cos(x**2)
# O método de 3/8 de simpson
def regra_de_simpson38( limite_inferior, limite_superior, sub_intervalo):
    # calculo do intervalo
    h = (limite_superior - limite_inferior) / sub_intervalo
    # Encontrando a soma
    integracao = f(limite_inferior) + f(limite_superior)
    for i in range(1,sub_intervalo):
        k = limite_inferior + i*h
        if i%2 == 0:
            integracao = integracao + 2 * f(k)
        else:
            integracao = integracao + 3 * f(k)
    # valor final da integral
    integracao = integracao * 3 * h / 8
    return integracao
for sub_intervalo in range(1,17):
    # entradas da integração
    limite_inferior = 0
    limite_superior = np.pi
    # Chamando a funcao pela regra de 3/8 de simpson
    r3 = regra_de_simpson38( limite_inferior, limite_superior, sub_intervalo)
    print(f'A integração pela regra de 3/8 de simpson é {r3}')
# Out:
# A integração pela regra de 3/8 de simpson é 0.11464610701417974
# A integração pela regra de 3/8 de simpson é -1.3231923133905117
# A integração pela regra de 3/8 de simpson é 0.32468566910482255
# A integração pela regra de 3/8 de simpson é 0.946736143906075
# A integração pela regra de 3/8 de simpson é 0.494601098695391
# A integração pela regra de 3/8 de simpson é 0.6752631340818972
# A integração pela regra de 3/8 de simpson é 0.6388900899664317
# A integração pela regra de 3/8 de simpson é 0.5561187956754492
# A integração pela regra de 3/8 de simpson é 0.6298667166969353
# A integração pela regra de 3/8 de simpson é 0.5392206121625803
# A integração pela regra de 3/8 de simpson é 0.6077227041561502
# A integração pela regra de 3/8 de simpson é 0.5356990046644922
# A integração pela regra de 3/8 de simpson é 0.5920300935249408
# A integração pela regra de 3/8 de simpson é 0.5342322693965141
# A integração pela regra de 3/8 de simpson é 0.5812680870254198
# A integração pela regra de 3/8 de simpson é 0.5333531017368367

# %%
# 4.e
from scipy.integrate import quad
def f(x):
    return np.cos(x**2)
res, erro = quad(f, 0, np.pi)
print(res)
# Out:
# 0.5656935136066826

# %%
#4.f
errotrap = np.absolute(res - r1)
erro3simp = np.absolute(res - r2)
erro8simp = np.absolute(res - r3)
print(f'Erro absoluto para;\n Por trapézio {errotrap}\n Por 1/3 de Simpson {erro3simp}\n Por 3/8 de simpson {erro8simp}\n')
# Out:
# Erro absoluto para;
#  Por trapézio 0.008835016007606944
#  Por 1/3 de Simpson 0.0005292413729438561
#  Por 3/8 de simpson 0.03234041186984593
