# %%
## MÉTODO DE Gauss-Seidel ##
E1=[]
I1=[]
tem=[]
# DETERMINANDO AS EQUAÇÕES
def x1i(a,b,c,d,e):
    return ( 6 - b - c ) / 4
def x2i(a,b,c,d,e):
    return ( 6 - c - d + a ) / (-3)
def x3i(a,b,c,d,e):
    return ( 2*a + b - d - e - 6 ) / (-5)
def x4i(a,b,c,d,e):
    return ( - a - b - c - 6 ) / (-4)
def x5i(a,b,c,d,e):
    return ( 2*b - c + d - 6 ) / (-4)
# VALORES INICIAIS DO LAÇO DE REPETIÇÃO
x10 = 0
x20 = 0
x30 = 0
x40 = 0
x50 = 0
# TOLERANCIA DA QUESTÃO
e = 10**(-7)
# CONTADOR PARA O LAÇO
n = 1
l = 50
# l é o limite de iteração
# CONDIÇÃO PARA INICIAR O LAÇO
c = True
# FUNÇÃO PARA CRIAR TABELA
def ct(c,n,x10,x20,x30,x40,x50,errox1,errox2,errox3,errox4,errox5):
    k=' '
    if n==1:
        print(f"Iterações{k*7}x1.1{k*10}x2.1{k*10}x3.1{k*13}x4.1{k*11}x5.1{k*8}erro(x1){k*8}erro(x2){k*8}erro(x3){k*8}erro(x4){k*8}erro(x5){k*8}")
        print("-"*160)
    if c!=False:
        print(f'''|{n:3}|     |{x10: 7.7f}|     |{x20: 7.7f}|    |{x30: 7.7f}|   |{x40: 7.7f}|    |{x50: 7.7f}|  |{errox1: 7.7f}|   |{errox2: 7.7f}|   |{errox3: 7.7f}|   |{errox4: 7.7f}|   |{errox5: 7.7f}|''')
    if c==False:    
        print("-"*160)
        print("\n\n")
while c:
   # CALCULO DOS VALORES
    x11 = x1i(x10,x20,x30,x40,x50) # O que muda do método de Gauss-Jacobi para Gauss-Seidel é apenas esse ponto
    x21 = x2i(x11,x20,x30,x40,x50) # que é substituido as variaveis pelas mais atuais 
    x31 = x3i(x11,x21,x30,x40,x50)
    x41 = x4i(x11,x21,x31,x40,x50)
    x51 = x5i(x11,x21,x31,x41,x50)
    # CALCULO DOS ERROS
    errox1 = abs(x11-x10)
    errox2 = abs(x21-x20)
    errox3 = abs(x31-x30)
    errox4 = abs(x41-x40)
    errox5 = abs(x51-x50)
    # Para escolher o maior erro entre os cinco, criamos um vetor temporário
    # Adicionamos os cinco,esxolhemos o maior, separamos, depois escolhemos o maior, depois limpa o vetor principal e repete a ação
    tem=[]
    tem.append(errox1)
    tem.append(errox2)
    tem.append(errox3)
    tem.append(errox4)
    tem.append(errox5)
    E1.append(max(tem))
    I1.append(n)
    tem.clear()
    ct(c,n,x11,x21,x31,x41,x51,errox1,errox2,errox3,errox4,errox5)
    # ICREMENTA O CONTADOR, E SUBSTITUI OS NOVOS VALORES 
    n += 1
    x10 = x11
    x20 = x21
    x30 = x31
    x40 = x41
    x50 = x51   
    if n>l:
        c=False
    c = errox1>e and errox2>e and errox3>e and errox4>e and errox5>e
ct(c,n,x11,x21,x31,x41,x51,errox1,errox2,errox3,errox4,errox5)
# Out:
# Iterações       x1.1          x2.1          x3.1             x4.1           x5.1        erro(x1)        erro(x2)        erro(x3)        erro(x4)        erro(x5)
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  1|     | 1.5000000|     |-2.5000000|    | 1.1000000|   | 1.5250000|    | 2.6437500|  | 1.5000000|   | 2.5000000|   | 1.1000000|   | 1.5250000|   | 2.6437500|
# |  2|     | 1.8500000|     |-1.7416667|    | 1.6420833|   | 1.9376042|    | 2.2969531|  | 0.3500000|   | 0.7583333|   | 0.5420833|   | 0.4126042|   | 0.3467969|
# |  3|     | 1.5248958|     |-1.3150694|    | 1.6999670|   | 1.9774484|    | 2.0881644|  | 0.3251042|   | 0.4265972|   | 0.0578837|   | 0.0398442|   | 0.2087887|
# |  4|     | 1.4037756|     |-1.2421201|    | 1.7000363|   | 1.9654230|    | 2.0547134|  | 0.1211202|   | 0.0729494|   | 0.0000693|   | 0.0120254|   | 0.0334510|
# ...

# %%
## MÉTODO DE Gauss-Seidel COM RELAXAMENTO 0.90 ##
E2=[]
I2=[]
tem=[]
# DETERMINANDO AS EQUAÇÕES
def x1i(w,a,b,c,d,e):
    return w*( 6 - b - c ) / 4
def x2i(w,a,b,c,d,e):
    return w*( 6 - c - d + a ) / (-3)
def x3i(w,a,b,c,d,e):
    return w*( 2*a + b - d - e - 6 ) / (-5)
def x4i(w,a,b,c,d,e):
    return w*( - a - b - c - 6 ) / (-4)
def x5i(w,a,b,c,d,e):
    return w*( 2*b - c + d - 6 ) / (-4)
# VALORES INICIAIS DO LAÇO DE REPETIÇÃO
x10 = 0
x20 = 0
x30 = 0
x40 = 0
x50 = 0
# TOLERANCIA DA QUESTÃO
e = 10**(-7)
# CONTADOR PARA O LAÇO
n = 1
l = 50
# l é o limite de iteração
# W de relaxamento
w = 0.90
# CONDIÇÃO PARA INICIAR O LAÇO
c = True
# FUNÇÃO PARA CRIAR TABELA
def ct(c,n,x10,x20,x30,x40,x50,errox1,errox2,errox3,errox4,errox5):
    k=' '
    if n==1:
        print(f"Iterações{k*7}x1.1{k*10}x2.1{k*10}x3.1{k*13}x4.1{k*11}x5.1{k*8}erro(x1){k*8}erro(x2){k*8}erro(x3){k*8}erro(x4){k*8}erro(x5){k*8}")
        print("-"*160)
    if c!=False:
        print(f'''|{n:3}|     |{x10: 7.7f}|     |{x20: 7.7f}|    |{x30: 7.7f}|   |{x40: 7.7f}|    |{x50: 7.7f}|  |{errox1: 7.7f}|   |{errox2: 7.7f}|   |{errox3: 7.7f}|   |{errox4: 7.7f}|   |{errox5: 7.7f}|''')
    if c==False:    
        print("-"*160)
        print("\n\n")
while c:
   # CALCULO DOS VALORES
    x11 = x1i(w,x10,x20,x30,x40,x50) # O que muda do método de Gauss-Jacobi para Gauss-Seidel é apenas esse ponto
    x21 = x2i(w,x11,x20,x30,x40,x50) # que é substituido as variaveis pelas mais atuais 
    x31 = x3i(w,x11,x21,x30,x40,x50)
    x41 = x4i(w,x11,x21,x31,x40,x50)
    x51 = x5i(w,x11,x21,x31,x41,x50)
    # CALCULO DOS ERROS
    errox1 = abs(x11-x10)
    errox2 = abs(x21-x20)
    errox3 = abs(x31-x30)
    errox4 = abs(x41-x40)
    errox5 = abs(x51-x50)
    # Para escolher o maior erro entre os cinco, criamos um vetor temporário
    # Adicionamos os cinco,esxolhemos o maior, separamos, depois escolhemos o maior, depois limpa o vetor principal e repete a ação
    tem=[]
    tem.append(errox1)
    tem.append(errox2)
    tem.append(errox3)
    tem.append(errox4)
    tem.append(errox5)
    E2.append(max(tem))
    I2.append(n)
    tem.clear()
    ct(c,n,x11,x21,x31,x41,x51,errox1,errox2,errox3,errox4,errox5)
    # ICREMENTA O CONTADOR, E SUBSTITUI OS NOVOS VALORES 
    n += 1
    x10 = x11
    x20 = x21
    x30 = x31
    x40 = x41
    x50 = x51   
    if n>l:
        c=False
    c = errox1>e and errox2>e and errox3>e and errox4>e and errox5>e
ct(c,n,x11,x21,x31,x41,x51,errox1,errox2,errox3,errox4,errox5)
# Out:
# Iterações       x1.1          x2.1          x3.1             x4.1           x5.1        erro(x1)        erro(x2)        erro(x3)        erro(x4)        erro(x5)
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  1|     | 1.3500000|     |-2.2050000|    | 0.9909000|   | 1.3805775|    | 2.2545726|  | 1.3500000|   | 2.2050000|   | 0.9909000|   | 1.3805775|   | 2.2545726|
# |  2|     | 1.6231725|     |-1.5755085|    | 1.4335764|   | 1.6832791|    | 2.0027957|  | 0.2731725|   | 0.6294915|   | 0.4426764|   | 0.3027016|   | 0.2517768|
# |  3|     | 1.3819347|     |-1.2795238|    | 1.4763112|   | 1.7052125|    | 1.8742829|  | 0.2412378|   | 0.2959847|   | 0.0427348|   | 0.0219334|   | 0.1285128|
# |  4|     | 1.3057228|     |-1.2372597|    | 1.4769557|   | 1.6977192|    | 1.8570951|  | 0.0762119|   | 0.0422640|   | 0.0006445|   | 0.0074933|   | 0.0171878|
# ...

# %%
## MÉTODO DE Gauss-Seidel COM RELAXAMENTO 1.00 ##
E3=[]
I3=[]
tem=[]
# DETERMINANDO AS EQUAÇÕES
def x1i(w,a,b,c,d,e):
    return w*( 6 - b - c ) / 4
def x2i(w,a,b,c,d,e):
    return w*( 6 - c - d + a ) / (-3)
def x3i(w,a,b,c,d,e):
    return w*( 2*a + b - d - e - 6 ) / (-5)
def x4i(w,a,b,c,d,e):
    return w*( - a - b - c - 6 ) / (-4)
def x5i(w,a,b,c,d,e):
    return w*( 2*b - c + d - 6 ) / (-4)
# VALORES INICIAIS DO LAÇO DE REPETIÇÃO
x10 = 0
x20 = 0
x30 = 0
x40 = 0
x50 = 0
# TOLERANCIA DA QUESTÃO
e = 10**(-7)
# CONTADOR PARA O LAÇO
n = 1
l = 50
# l é o limite de iteração
# W de relaxamento
w = 1.00
# CONDIÇÃO PARA INICIAR O LAÇO
c = True
# FUNÇÃO PARA CRIAR TABELA
def ct(c,n,x10,x20,x30,x40,x50,errox1,errox2,errox3,errox4,errox5):
    k=' '
    if n==1:
        print(f"Iterações{k*7}x1.1{k*10}x2.1{k*10}x3.1{k*13}x4.1{k*11}x5.1{k*8}erro(x1){k*8}erro(x2){k*8}erro(x3){k*8}erro(x4){k*8}erro(x5){k*8}")
        print("-"*160)
    if c!=False:
        print(f'''|{n:3}|     |{x10: 7.7f}|     |{x20: 7.7f}|    |{x30: 7.7f}|   |{x40: 7.7f}|    |{x50: 7.7f}|  |{errox1: 7.7f}|   |{errox2: 7.7f}|   |{errox3: 7.7f}|   |{errox4: 7.7f}|   |{errox5: 7.7f}|''')
    if c==False:    
        print("-"*160)
        print("\n\n")
while c:
   # CALCULO DOS VALORES
    x11 = x1i(w,x10,x20,x30,x40,x50) # O que muda do método de Gauss-Jacobi para Gauss-Seidel é apenas esse ponto
    x21 = x2i(w,x11,x20,x30,x40,x50) # que é substituido as variaveis pelas mais atuais 
    x31 = x3i(w,x11,x21,x30,x40,x50)
    x41 = x4i(w,x11,x21,x31,x40,x50)
    x51 = x5i(w,x11,x21,x31,x41,x50)
    # CALCULO DOS ERROS
    errox1 = abs(x11-x10)
    errox2 = abs(x21-x20)
    errox3 = abs(x31-x30)
    errox4 = abs(x41-x40)
    errox5 = abs(x51-x50)
    # Para escolher o maior erro entre os cinco, criamos um vetor temporário
    # Adicionamos os cinco,esxolhemos o maior, separamos, depois escolhemos o maior, depois limpa o vetor principal e repete a ação
    tem=[]
    tem.append(errox1)
    tem.append(errox2)
    tem.append(errox3)
    tem.append(errox4)
    tem.append(errox5)
    E3.append(max(tem))
    I3.append(n)
    tem.clear()
    ct(c,n,x11,x21,x31,x41,x51,errox1,errox2,errox3,errox4,errox5)
    # ICREMENTA O CONTADOR, E SUBSTITUI OS NOVOS VALORES 
    n += 1
    x10 = x11
    x20 = x21
    x30 = x31
    x40 = x41
    x50 = x51   
    if n>l:
        c=False
    c = errox1>e and errox2>e and errox3>e and errox4>e and errox5>e
ct(c,n,x11,x21,x31,x41,x51,errox1,errox2,errox3,errox4,errox5)
# Out:
# Iterações       x1.1          x2.1          x3.1             x4.1           x5.1        erro(x1)        erro(x2)        erro(x3)        erro(x4)        erro(x5)
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  1|     | 1.5000000|     |-2.5000000|    | 1.1000000|   | 1.5250000|    | 2.6437500|  | 1.5000000|   | 2.5000000|   | 1.1000000|   | 1.5250000|   | 2.6437500|
# |  2|     | 1.8500000|     |-1.7416667|    | 1.6420833|   | 1.9376042|    | 2.2969531|  | 0.3500000|   | 0.7583333|   | 0.5420833|   | 0.4126042|   | 0.3467969|
# |  3|     | 1.5248958|     |-1.3150694|    | 1.6999670|   | 1.9774484|    | 2.0881644|  | 0.3251042|   | 0.4265972|   | 0.0578837|   | 0.0398442|   | 0.2087887|
# |  4|     | 1.4037756|     |-1.2421201|    | 1.7000363|   | 1.9654230|    | 2.0547134|  | 0.1211202|   | 0.0729494|   | 0.0000693|   | 0.0120254|   | 0.0334510|
# ...

# %%
## MÉTODO DE Gauss-Seidel COM RELAXAMENTO 1.10 ##
E4=[]
I4=[]
tem=[]
# DETERMINANDO AS EQUAÇÕES
def x1i(w,a,b,c,d,e):
    return w*( 6 - b - c ) / 4
def x2i(w,a,b,c,d,e):
    return w*( 6 - c - d + a ) / (-3)
def x3i(w,a,b,c,d,e):
    return w*( 2*a + b - d - e - 6 ) / (-5)
def x4i(w,a,b,c,d,e):
    return w*( - a - b - c - 6 ) / (-4)
def x5i(w,a,b,c,d,e):
    return w*( 2*b - c + d - 6 ) / (-4)
# VALORES INICIAIS DO LAÇO DE REPETIÇÃO
x10 = 0
x20 = 0
x30 = 0
x40 = 0
x50 = 0
# TOLERANCIA DA QUESTÃO
e = 10**(-7)
# CONTADOR PARA O LAÇO
n = 1
l = 50
# l é o limite de iteração
# W de relaxamento
w = 1.10
# CONDIÇÃO PARA INICIAR O LAÇO
c = True
# FUNÇÃO PARA CRIAR TABELA
def ct(c,n,x10,x20,x30,x40,x50,errox1,errox2,errox3,errox4,errox5):
    k=' '
    if n==1:
        print(f"Iterações{k*7}x1.1{k*10}x2.1{k*10}x3.1{k*13}x4.1{k*11}x5.1{k*8}erro(x1){k*8}erro(x2){k*8}erro(x3){k*8}erro(x4){k*8}erro(x5){k*8}")
        print("-"*160)
    if c!=False:
        print(f'''|{n:3}|     |{x10: 7.7f}|     |{x20: 7.7f}|    |{x30: 7.7f}|   |{x40: 7.7f}|    |{x50: 7.7f}|  |{errox1: 7.7f}|   |{errox2: 7.7f}|   |{errox3: 7.7f}|   |{errox4: 7.7f}|   |{errox5: 7.7f}|''')
    if c==False:    
        print("-"*160)
        print("\n\n")
while c:
   # CALCULO DOS VALORES
    x11 = x1i(w,x10,x20,x30,x40,x50) # O que muda do método de Gauss-Jacobi para Gauss-Seidel é apenas esse ponto
    x21 = x2i(w,x11,x20,x30,x40,x50) # que é substituido as variaveis pelas mais atuais 
    x31 = x3i(w,x11,x21,x30,x40,x50)
    x41 = x4i(w,x11,x21,x31,x40,x50)
    x51 = x5i(w,x11,x21,x31,x41,x50)
    # CALCULO DOS ERROS
    errox1 = abs(x11-x10)
    errox2 = abs(x21-x20)
    errox3 = abs(x31-x30)
    errox4 = abs(x41-x40)
    errox5 = abs(x51-x50)
    # Para escolher o maior erro entre os cinco, criamos um vetor temporário
    # Adicionamos os cinco,esxolhemos o maior, separamos, depois escolhemos o maior, depois limpa o vetor principal e repete a ação
    tem=[]
    tem.append(errox1)
    tem.append(errox2)
    tem.append(errox3)
    tem.append(errox4)
    tem.append(errox5)
    E4.append(max(tem))
    I4.append(n)
    tem.clear()
    ct(c,n,x11,x21,x31,x41,x51,errox1,errox2,errox3,errox4,errox5)
    # ICREMENTA O CONTADOR, E SUBSTITUI OS NOVOS VALORES 
    n += 1
    x10 = x11
    x20 = x21
    x30 = x31
    x40 = x41
    x50 = x51   
    if n>l:
        c=False
    c = errox1>e and errox2>e and errox3>e and errox4>e and errox5>e
ct(c,n,x11,x21,x31,x41,x51,errox1,errox2,errox3,errox4,errox5)
# Out:
# Iterações       x1.1          x2.1          x3.1             x4.1           x5.1        erro(x1)        erro(x2)        erro(x3)        erro(x4)        erro(x5)
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  1|     | 1.6500000|     |-2.8050000|    | 1.2111000|   | 1.6654275|    | 3.0678099|  | 1.6500000|   | 2.8050000|   | 1.2111000|   | 1.6654275|   | 3.0678099|
# |  2|     | 2.0883225|     |-1.9109915|    | 1.8628685|   | 2.2110549|    | 2.6052941|  | 0.4383225|   | 0.8940085|   | 0.6517685|   | 0.5456274|   | 0.4625159|
# |  3|     | 1.6632338|     |-1.3160805|    | 1.9373116|   | 2.2782278|    | 2.2800923|  | 0.4250887|   | 0.5949110|   | 0.0744431|   | 0.0671730|   | 0.3252018|
# |  4|     | 1.4791615|     |-1.1966614|    | 1.9352649|   | 2.2598854|    | 2.2188931|  | 0.1840724|   | 0.1194191|   | 0.0020467|   | 0.0183425|   | 0.0611992|
# ...

# %%
## MÉTODO DE Gauss-Seidel COM RELAXAMENTO 1.20 ##
E5=[]
I5=[]
tem=[]
# DETERMINANDO AS EQUAÇÕES
def x1i(w,a,b,c,d,e):
    return w*( 6 - b - c ) / 4
def x2i(w,a,b,c,d,e):
    return w*( 6 - c - d + a ) / (-3)
def x3i(w,a,b,c,d,e):
    return w*( 2*a + b - d - e - 6 ) / (-5)
def x4i(w,a,b,c,d,e):
    return w*( - a - b - c - 6 ) / (-4)
def x5i(w,a,b,c,d,e):
    return w*( 2*b - c + d - 6 ) / (-4)
# VALORES INICIAIS DO LAÇO DE REPETIÇÃO
x10 = 0
x20 = 0
x30 = 0
x40 = 0
x50 = 0
# TOLERANCIA DA QUESTÃO
e = 10**(-7)
# CONTADOR PARA O LAÇO
n = 1
l = 50
# l é o limite de iteração
# W de relaxamento
w = 1.20
# CONDIÇÃO PARA INICIAR O LAÇO
c = True
# FUNÇÃO PARA CRIAR TABELA
def ct(c,n,x10,x20,x30,x40,x50,errox1,errox2,errox3,errox4,errox5):
    k=' '
    if n==1:
        print(f"Iterações{k*7}x1.1{k*10}x2.1{k*10}x3.1{k*13}x4.1{k*11}x5.1{k*8}erro(x1){k*8}erro(x2){k*8}erro(x3){k*8}erro(x4){k*8}erro(x5){k*8}")
        print("-"*160)
    if c!=False:
        print(f'''|{n:3}|     |{x10: 7.7f}|     |{x20: 7.7f}|    |{x30: 7.7f}|   |{x40: 7.7f}|    |{x50: 7.7f}|  |{errox1: 7.7f}|   |{errox2: 7.7f}|   |{errox3: 7.7f}|   |{errox4: 7.7f}|   |{errox5: 7.7f}|''')
    if c==False:    
        print("-"*160)
        print("\n\n")
while c:
   # CALCULO DOS VALORES
    x11 = x1i(w,x10,x20,x30,x40,x50) # O que muda do método de Gauss-Jacobi para Gauss-Seidel é apenas esse ponto
    x21 = x2i(w,x11,x20,x30,x40,x50) # que é substituido as variaveis pelas mais atuais 
    x31 = x3i(w,x11,x21,x30,x40,x50)
    x41 = x4i(w,x11,x21,x31,x40,x50)
    x51 = x5i(w,x11,x21,x31,x41,x50)
    # CALCULO DOS ERROS
    errox1 = abs(x11-x10)
    errox2 = abs(x21-x20)
    errox3 = abs(x31-x30)
    errox4 = abs(x41-x40)
    errox5 = abs(x51-x50)
    # Para escolher o maior erro entre os cinco, criamos um vetor temporário
    # Adicionamos os cinco,esxolhemos o maior, separamos, depois escolhemos o maior, depois limpa o vetor principal e repete a ação
    tem=[]
    tem.append(errox1)
    tem.append(errox2)
    tem.append(errox3)
    tem.append(errox4)
    tem.append(errox5)
    E5.append(max(tem))
    I5.append(n)
    tem.clear()
    ct(c,n,x11,x21,x31,x41,x51,errox1,errox2,errox3,errox4,errox5)
    # ICREMENTA O CONTADOR, E SUBSTITUI OS NOVOS VALORES 
    n += 1
    x10 = x11
    x20 = x21
    x30 = x31
    x40 = x41
    x50 = x51   
    if n>l:
        c=False
    c = errox1>e and errox2>e and errox3>e and errox4>e and errox5>e
ct(c,n,x11,x21,x31,x41,x51,errox1,errox2,errox3,errox4,errox5)
# Out:
# Iterações       x1.1          x2.1          x3.1             x4.1           x5.1        erro(x1)        erro(x2)        erro(x3)        erro(x4)        erro(x5)
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  1|     | 1.8000000|     |-3.1200000|    | 1.3248000|   | 1.8014400|    | 3.5290080|  | 1.8000000|   | 3.1200000|   | 1.3248000|   | 1.8014400|   | 3.5290080|
# |  2|     | 2.3385600|     |-2.0849280|    | 2.0971814|   | 2.5052440|    | 2.9285380|  | 0.5385600|   | 1.0350720|   | 0.7723814|   | 0.7038040|   | 0.6004700|
# |  3|     | 1.7963240|     |-1.2775594|    | 2.1884864|   | 2.6121753|    | 2.4394290|  | 0.5422360|   | 0.8073686|   | 0.0913050|   | 0.1069313|   | 0.4891090|
# |  4|     | 1.5267219|     |-1.0904241|    | 2.1812603|   | 2.5852674|    | 2.3330523|  | 0.2696021|   | 0.1871353|   | 0.0072261|   | 0.0269079|   | 0.1063767|
# ...

# %%
## MÉTODO DE JACOBI ##
E6=[]
I6=[]
# DETERMINANDO AS EQUAÇÕES
def x1i(a,b,c,d,e):
    return ( 6 - b - c ) / 4
def x2i(a,b,c,d,e):
    return ( 6 - c - d + a ) / (-3)
def x3i(a,b,c,d,e):
    return ( 2*a + b - d - e - 6 ) / (-5)
def x4i(a,b,c,d,e):
    return ( - a - b - c - 6 ) / (-4)
def x5i(a,b,c,d,e):
    return ( 2*b - c + d - 6 ) / (-4)
# VALORES INICIAIS DO LAÇO DE REPETIÇÃO
x10 = 0
x20 = 0
x30 = 0
x40 = 0
x50 = 0
# TOLERANCIA DA QUESTÃO
e = 10**(-7)
# CONTADOR PARA O LAÇO
n = 1
l = 50
# l é o limite de iteração
# CONDIÇÃO PARA INICIAR O LAÇO
c = True
# FUNÇÃO PARA CRIAR TABELA
def ct(c,n,x10,x20,x30,x40,x50,errox1,errox2,errox3,errox4,errox5):
    k=' '
    if n==1:
        print(f"Iterações{k*7}x1.1{k*10}x2.1{k*10}x3.1{k*13}x4.1{k*11}x5.1{k*8}erro(x1){k*8}erro(x2){k*8}erro(x3){k*8}erro(x4){k*8}erro(x5){k*8}")
        print("-"*160)    
    if c!=False:
        print(f'|{n:3}|     |{x10: 7.7f}|     |{x20: 7.7f}|    |{x30: 7.7f}|   |{x40: 7.7f}|    |{x50: 7.7f}|  |{errox1: 7.7f}|   |{errox2: 7.7f}|   |{errox3: 7.7f}|   |{errox4: 7.7f}|   |{errox5: 7.7f}|')
    if c==False:
        print("-"*160)
        print("\n\n")
while c:
   # CALCULO DOS VALORES
    x11 = x1i(x10,x20,x30,x40,x50)
    x21 = x2i(x10,x20,x30,x40,x50)
    x31 = x3i(x10,x20,x30,x40,x50)
    x41 = x4i(x10,x20,x30,x40,x50)
    x51 = x5i(x10,x20,x30,x40,x50)
    # CALCULO DOS ERROS
    errox1 = abs(x11-x10)
    errox2 = abs(x21-x20)
    errox3 = abs(x31-x30)
    errox4 = abs(x41-x40)
    errox5 = abs(x51-x50)  
    # para escolher o maior erro entre os cinco, criamos um vetor temporário
    # adicionamos os cinco,esxolhemos o maior, separamos, depois escolhemos o maior, depois limpa o vetor principal e repete a ação
    tem=[]
    tem.append(errox1)
    tem.append(errox2)
    tem.append(errox3)
    tem.append(errox4)
    tem.append(errox5)
    E6.append(max(tem))
    tem.clear()
    I6.append(n)
    ct(c,n,x11,x21,x31,x41,x51,errox1,errox2,errox3,errox4,errox5)
    # ICREMENTA O CONTADOR, E SUBSTITUI OS NOVOS VALORES 
    n += 1
    x10 = x11
    x20 = x21
    x30 = x31
    x40 = x41
    x50 = x51
    if n>l:
        c=False
    c = errox1>e and errox2>e and errox3>e and errox4>e and errox5>e
ct(c,n,x11,x21,x31,x41,x51,errox1,errox2,errox3,errox4,errox5)
# Out:
# Iterações       x1.1          x2.1          x3.1             x4.1           x5.1        erro(x1)        erro(x2)        erro(x3)        erro(x4)        erro(x5)
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  1|     | 1.5000000|     |-2.0000000|    | 1.2000000|   | 1.5000000|    | 1.5000000|  | 1.5000000|   | 2.0000000|   | 1.2000000|   | 1.5000000|   | 1.5000000|
# |  2|     | 1.7000000|     |-1.6000000|    | 1.6000000|   | 1.6750000|    | 2.4250000|  | 0.2000000|   | 0.4000000|   | 0.4000000|   | 0.1750000|   | 0.9250000|
# |  3|     | 1.5000000|     |-1.4750000|    | 1.6600000|   | 1.9250000|    | 2.2812500|  | 0.2000000|   | 0.1250000|   | 0.0600000|   | 0.2500000|   | 0.1437500|
# |  4|     | 1.4537500|     |-1.3050000|    | 1.7362500|   | 1.9212500|    | 2.1712500|  | 0.0462500|   | 0.1700000|   | 0.0762500|   | 0.0037500|   | 0.1100000|
# ...

# %%
#>>>>>>>>>>>>>>>>> COMO CRIAR GRAFICOS !!! <<<<<<<<<<<<#
import matplotlib.pyplot as plt #biblioteca de graficos do python
plt.figure(figsize=(10, 10)) #criar o quadro branco de tamanho 10x10
plt.style.use('classic') #o estilo de cores do grafico
plt.plot(I6,E6, 'o-', color='red', label = 'Jacobi')
plt.plot(I1,E1, 'o-', color='blue', label = 'Gauss-Seidel')
plt.plot(I2,E2, 'o-', color='yellow', label = 'Gauss-Seidel com relaxamento 0.9')
plt.plot(I3,E3, 'o-', color='green', label = 'Gauss-Seidel com relaxamento 1.00')
plt.plot(I4,E4, 'o-', color='black', label = 'Gauss-Seidel com relaxamento 1.10')
plt.plot(I5,E5, 'o-', color='orange', label = 'Gauss-Seidel com relaxamento 1.20')
plt.title('Variação da convergência/iterações')  # titulo do grafico 
plt.xlabel('Quantidade de iterações')  #legenda em x
plt.ylabel('Variação da convergência')  #legenda em y
plt.legend()  # Esse é para apresentar os nomes (label) de cada linha 
plt.xticks(I6) # para apresentar todos os valores de x visualmente
plt.ylim(-0.4,3.6)
plt.grid()
plt.show() # para apresentar o grafico
print('\n')

# %%
#>>>>>>>>>>>>>>>>> COMO CRIAR GRAFICOS !!! <<<<<<<<<<<<#
import matplotlib.pyplot as plt #biblioteca de graficos do python
plt.figure(figsize=(10, 10)) #criar o quadro branco de tamanho 10x10
plt.style.use('classic') #o estilo de cores do grafico
plt.plot(I6,E6, 'o-', color='red', label = 'Jacobi')
plt.plot(I1,E1, 'o-', color='blue', label = 'Gauss-Seidel')
plt.plot(I2,E2, 'o-', color='yellow', label = 'Gauss-Seidel com relaxamento 0.9')
plt.plot(I3,E3, 'o-', color='green', label = 'Gauss-Seidel com relaxamento 1.00')
plt.plot(I4,E4, 'o-', color='black', label = 'Gauss-Seidel com relaxamento 1.10')
plt.plot(I5,E5, 'o-', color='orange', label = 'Gauss-Seidel com relaxamento 1.20')
plt.title('Variação da convergência/iterações')  # titulo do grafico 
plt.xlabel('Quantidade de iterações')  #legenda em x
plt.ylabel('Variação da convergência')  #legenda em y
plt.legend()  # Esse é para apresentar os nomes (label) de cada linha 
plt.xticks(I6) # para apresentar todos os valores de x visualmente
plt.ylim(-0.4,2)
plt.xlim(1,8)
plt.grid()
plt.show() # para apresentar o grafico
print('\n')
