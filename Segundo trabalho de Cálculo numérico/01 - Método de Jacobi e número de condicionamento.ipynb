# %%
## MÉTODO DE JACOBI ##
#para calcular o numero de condicionamento
import numpy as np
from numpy import linalg as la
#||X|| * ||X^-1|| 
A = np.array([[71,40],[51,30]], dtype='double') #criando a matriz
B = np.linalg.inv(A) # inversão da matriz
C = la.norm(A, 1)
D = la.norm(B, 1) #Calculo da norma para 1
print(f'Número de condicionamento\n Para norma 1:\n{np.multiply(C,D)}\n')  
E = la.norm(A, 2)
F = la.norm(B, 2) #calculo norma 2

print(f'Para norma 2:\n{np.multiply(E,F)}\n')  
G = la.norm(A, np.inf)
H = la.norm(B, np.inf) #calculo norma infinita
print(f'Para norma infinita:\n{np.multiply(G,H)}\n')
# DETERMINANDO AS EQUAÇÕES
'''
a
71𝑥 + 40𝑦 = 100
51𝑥 + 30𝑦 = 70
'''
def xi(x,y):
    return (100 - 40*y)/71
def yi(x,y):
    return (70 - 51*x)/30
print(f'\nx=(100 - 40*y)/71\n y=(70 - 51*x)/30\n')
# VALORES INICIAIS DO LAÇO DE REPETIÇÃO
x0 = 0
y0 = 0
# TOLERANCIA DA QUESTÃO
e = 10**(-7)
# CONTADOR PARA O LAÇO
n = 1
l = 10000
# l é o limite de iteração
print(f'x0={x0}\ny0={y0}\nTolerância={e:.7f}\nLimite de iterações={l}\n')
# CONDIÇÃO PARA INICIAR O LAÇO
c = True
# FUNÇÃO PARA CRIAR TABELA
def ct(c,n,x0,y0,errox,erroy):
    k=' '
    if n==1:
        print(f"Iterações{k*12}xi{k*15}yi{k*19}erro(x){k*15}erro(y){k*15}")
        print("-"*100)
    print(f'|{n:3}|         |{x0: 7.7f}|         |{y0: 7.7f}|        |{errox: 7.7f}|        |{erroy: 7.7f}|')
    if c==False and n>=l :
        print("-"*100)
        print("\n\n")
while c :
    # CALCULO DOS VALORES
    x1 = xi(x0,y0)
    y1 = yi(x0,y0)
    # CALCULO DOS ERROS
    errox = abs(x1-x0)/abs(x1)
    erroy = abs(y1-y0)/abs(y1)
    ct(c,n,x0,y0,errox,erroy)
    # INCREMENTA O CONTADOR, E SUBSTITUI OS NOVOS VALORES 
    n += 1
    x0 = x1
    y0 = y1
    if n >= l:
        c=False
        break
    c = errox>e and erroy>e
ct(c,n,x0,y0,errox,erroy)
# Out:
# Número de condicionamento
#  Para norma 1:
# 150.46666666666678
#
# Para norma 2:
# 112.68001420062153
#
# Para norma infinita:
# 150.46666666666678
#
#
# x=(100 - 40*y)/71
#  y=(70 - 51*x)/30
#
# x0=0
# y0=0
# Tolerância=0.0000001
# Limite de iterações=10000
#
# Iterações            xi               yi                   erro(x)               erro(y)
# ----------------------------------------------------------------------------------------------------
# |  1|         | 0.0000000|         | 0.0000000|        | 1.0000000|        | 1.0000000|
# |  2|         | 1.4084507|         | 2.3333333|        | 14.0000000|        | 39.2307692|
# |  3|         | 0.0938967|         |-0.0610329|        | 0.9349221|        | 1.0280778|
# |  4|         | 1.4428354|         | 2.1737089|        | 6.8489209|        | 19.1920310|
# |  5|         | 0.1838260|         |-0.1194869|        | 0.8754370|        | 1.0591276|
# ...

# %%
## MÉTODO DE JACOBI ##
#para calcular o numero de condicionamento
import numpy as np
from numpy import linalg as la
#||X|| * ||X^-1|| 
A = np.array([[71,40],[52,30]], dtype='double') #criando a matriz
B = np.linalg.inv(A) # inversão da matriz
C = la.norm(A, 1)
D = la.norm(B, 1) #Calculo da norma para 1
print(f'Número de condicionamento\n Para norma 1:\n{np.multiply(C,D)}\n')  
E = la.norm(A, 2)
F = la.norm(B, 2) #calculo norma 2

print(f'Para norma 2:\n{np.multiply(E,F)}\n')  
G = la.norm(A, np.inf)
H = la.norm(B, np.inf) #calculo norma infinita
print(f'Para norma infinita:\n{np.multiply(G,H)}\n')
# DETERMINANDO AS EQUAÇÕES
'''
b
71𝑥 + 40𝑦 = 100
52𝑥 + 30𝑦 = 70
'''
def xi(x,y):
    return (100 - 40*y)/71
def yi(x,y):
    return (70 - 52*x)/30
print(f'\nx=(100 - 40*y)/71\n y=(70 - 51*x)/30\n')
# VALORES INICIAIS DO LAÇO DE REPETIÇÃO
x0 = 0
y0 = 0
# TOLERANCIA DA QUESTÃO
e = 10**(-7)
# CONTADOR PARA O LAÇO
n = 1
l = 10000
# l é o limite de iteração
print(f'x0={x0}\ny0={y0}\nTolerância={e:.7f}\nLimite de iterações={l}\n')
# CONDIÇÃO PARA INICIAR O LAÇO
c = True
# FUNÇÃO PARA CRIAR TABELA
def ct(c,n,x0,y0,errox,erroy):
    k=' '
    if n==1:
        print(f"Iterações{k*12}xi{k*15}yi{k*19}erro(x){k*15}erro(y){k*15}")
        print("-"*100)
    print(f'|{n:3}|         |{x0: 7.7f}|         |{y0: 7.7f}|        |{errox: 7.7f}|        |{erroy: 7.7f}|')
    if c==False and n>=l :
        print("-"*100)
        print("\n\n")
while c :
    # CALCULO DOS VALORES
    x1 = xi(x0,y0)
    y1 = yi(x0,y0)
    # CALCULO DOS ERROS
    errox = abs(x1-x0)/abs(x1)
    erroy = abs(y1-y0)/abs(y1)
    ct(c,n,x0,y0,errox,erroy)
    # ICREMENTA O CONTADOR, E SUBSTITUI OS NOVOS VALORES 
    n += 1
    x0 = x1
    y0 = y1
    if n >= l:
        c=False
        break
    c = errox>e and erroy>e
ct(c,n,x0,y0,errox,erroy)
# Out:
# Número de condicionamento
#  Para norma 1:
# 273.06
#
# Para norma 2:
# 204.89511945427174
#
# Para norma infinita:
# 273.06
#
#
# x=(100 - 40*y)/71
#  y=(70 - 51*x)/30
#
# x0=0
# y0=0
# Tolerância=0.0000001
# Limite de iterações=10000
#
# Iterações            xi               yi                   erro(x)               erro(y)
# ----------------------------------------------------------------------------------------------------
# |  1|         | 0.0000000|         | 0.0000000|        | 1.0000000|        | 1.0000000|
# |  2|         | 1.4084507|         | 2.3333333|        | 14.0000000|        | 22.6086957|
# |  3|         | 0.0938967|         |-0.1079812|        | 0.9360936|        | 1.0497477|
# |  4|         | 1.4692852|         | 2.1705790|        | 6.9168646|        | 11.1700919|
# |  5|         | 0.1855893|         |-0.2134277|        | 0.8785960|        | 1.1060961|
# |  6|         | 1.5286916|         | 2.0116452|        | 4.5562635|        | 7.3579410|
# ...

# %%
## MÉTODO DE JACOBI ##
#para calcular o numero de condicionamento
import numpy as np
from numpy import linalg as la
#||X|| * ||X^-1|| 
A = np.array([[71,40],[51,30]], dtype='double') #criando a matriz
B = np.linalg.inv(A) # inversão da matriz
C = la.norm(A, 1)
D = la.norm(B, 1) #Calculo da norma para 1
print(f'Número de condicionamento\n Para norma 1:\n{np.multiply(C,D)}\n')  
E = la.norm(A, 2)
F = la.norm(B, 2) #calculo norma 2

print(f'Para norma 2:\n{np.multiply(E,F)}\n')  
G = la.norm(A, np.inf)
H = la.norm(B, np.inf) #calculo norma infinita
print(f'Para norma infinita:\n{np.multiply(G,H)}\n')
# DETERMINANDO AS EQUAÇÕES
'''
c
71𝑥 + 40𝑦 = 100,3
52𝑥 + 30𝑦 = 69,4
'''
def xi(x,y):
    return (100.3 - 40*y)/71
def yi(x,y):
    return (69.4 - 52*x)/30
print(f'\nx=(100 - 40*y)/71\n y=(70 - 51*x)/30\n')
# VALORES INICIAIS DO LAÇO DE REPETIÇÃO
x0 = 0
y0 = 0
# TOLERANCIA DA QUESTÃO
e = 10**(-7)
# CONTADOR PARA O LAÇO
n = 1
l = 10000
# l é o limite de iteração
print(f'x0={x0}\ny0={y0}\nTolerância={e:.7f}\nLimite de iterações={l}\n')
# CONDIÇÃO PARA INICIAR O LAÇO
c = True
# FUNÇÃO PARA CRIAR TABELA
def ct(c,n,x0,y0,errox,erroy):
    k=' '
    if n==1:
        print(f"Iterações{k*12}xi{k*15}yi{k*19}erro(x){k*15}erro(y){k*15}")
        print("-"*100)
    print(f'|{n:3}|         |{x0: 7.7f}|         |{y0: 7.7f}|        |{errox: 7.7f}|        |{erroy: 7.7f}|')
    if c==False and n>=l :
        print("-"*100)
        print("\n\n")
while c :
    # CALCULO DOS VALORES
    x1 = xi(x0,y0)
    y1 = yi(x0,y0)
    # CALCULO DOS ERROS
    errox = abs(x1-x0)/abs(x1)
    erroy = abs(y1-y0)/abs(y1)
    ct(c,n,x0,y0,errox,erroy)
    # ICREMENTA O CONTADOR, E SUBSTITUI OS NOVOS VALORES 
    n += 1
    x0 = x1
    y0 = y1
    if n >= l:
        c=False
        break
    c = errox>e and erroy>e
ct(c,n,x0,y0,errox,erroy)
# Out:
# Número de condicionamento
#  Para norma 1:
# 150.46666666666678
#
# Para norma 2:
# 112.68001420062153
#
# Para norma infinita:
# 150.46666666666678
#
#
# x=(100 - 40*y)/71
#  y=(70 - 51*x)/30
#
# x0=0
# y0=0
# Tolerância=0.0000001
# Limite de iterações=10000
#
# Iterações            xi               yi                   erro(x)               erro(y)
# ----------------------------------------------------------------------------------------------------
# |  1|         | 0.0000000|         | 0.0000000|        | 1.0000000|        | 1.0000000|
# |  2|         | 1.4126761|         | 2.3133333|        | 11.9141631|        | 18.0971548|
# |  3|         | 0.1093897|         |-0.1353052|        | 0.9265301|        | 1.0637113|
# |  4|         | 1.4889043|         | 2.1237246|        | 5.8863324|        | 8.9411121|
# |  5|         | 0.2162115|         |-0.2674342|        | 0.8616993|        | 1.1379546|
# |  6|         | 1.5633432|         | 1.9385667|        | 3.8774333|        | 5.8896718|
# ...
